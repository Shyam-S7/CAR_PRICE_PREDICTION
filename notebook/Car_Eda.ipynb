# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('/content/Cleaned_car_data (1).csv')
df.head(2)
# Out:
#      brand        model  color  year  price_in_euro  power_kw  power_ps  \
# 0  hyundai  Hyundai i10  black  2018        11555.0      49.0      67.0
# 1    honda   Honda CR-V    red  2018        24490.0     114.0     155.0
#
#   transmission_type fuel_type  fuel_consumption_l_100km  \
# 0            Manual    Petrol                       4.6
# 1         Automatic    Petrol                       7.5
#
#    fuel_consumption_g_km  mileage_in_km
# 0                  106.0        27782.0
# 1                  175.0        57000.0

# %%
df.shape
# Out:
# (85258, 12)

# %%
two=df[df['year']>=2010]#use for model training
two.head(2)
# Out:
#      brand        model  color  year  price_in_euro  power_kw  power_ps  \
# 0  hyundai  Hyundai i10  black  2018        11555.0      49.0      67.0
# 1    honda   Honda CR-V    red  2018        24490.0     114.0     155.0
#
#   transmission_type fuel_type  fuel_consumption_l_100km  \
# 0            Manual    Petrol                       4.6
# 1         Automatic    Petrol                       7.5
#
#    fuel_consumption_g_km  mileage_in_km
# 0                  106.0        27782.0
# 1                  175.0        57000.0

# %%
two.shape
# Out:
# (73908, 12)

# %%
len(df)-len(two)
# Out:
# 11350

# %%
sns.boxplot(df['price_in_euro'])
# Out:
# <Axes: ylabel='price_in_euro'>

# %%
dff=df[df['price_in_euro']<=50000]
dff.shape#final data
# Out:
# (78612, 12)

# %%
sns.boxplot(dff['price_in_euro'])
# Out:
# <Axes: ylabel='price_in_euro'>

# %%
len(df)-len(dff)  #to removeoutlier
# Out:
# 6646

# %%
85258-78612
# Out:
# 6646

# %% [markdown]
# Univariant

# %%
value=df['transmission_type'].value_counts()
label=df['transmission_type'].value_counts().index
plt.pie(value,labels=label,autopct='%1.1f%%')

plt.show()#transmission_type

# %%
plt.pie(df['fuel_type'].value_counts(),labels=df['fuel_type'].value_counts().index,autopct='%1.1f%%')
plt.show()#fuel

# %%
sns.distplot(two['price_in_euro'],bins=20)
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.title('Price Distribution')
plt.show()#price
# Out:
# /tmp/ipython-input-3414208822.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(two['price_in_euro'],bins=20)

# %%
sns.distplot(two['fuel_consumption_l_100km'],bins=20)
plt.xlabel('fuel_consumption_l_100km')
plt.ylabel('Frequency')
plt.title('fuel_consumption_l_100km')
plt.show()#
# Out:
# /tmp/ipython-input-3120050796.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(two['fuel_consumption_l_100km'],bins=20)

# %%
fig, ax = plt.subplots(5, 3, figsize=(25, 25))

for col, ax in zip(df.columns, ax.flatten()):
    sns.histplot(df[col], ax=ax, kde=True)
    ax.set_title(col)

plt.tight_layout()
plt.show()

# %%
    numerical_cols = df.select_dtypes(include=['number']).columns
    n_cols = 3 # Adjust as needed for desired layout
    n_rows = (len(numerical_cols) + n_cols - 1) // n_cols # Calculate rows dynamically
    fig, axes = plt.subplots(n_rows, n_cols, figsize=(n_cols * 5, n_rows * 4))
    axes = axes.flatten() # Flatten the 2D array of axes for easy iteration
    for i, col in enumerate(numerical_cols):
        sns.histplot(data=df, x=col, kde=True, ax=axes[i]) # Using histplot with kde=True
        axes[i].set_title(f'Distribution of {col}')
        axes[i].set_xlabel(col)
        axes[i].set_ylabel('Density') # Or 'Count' if kde=False

    plt.tight_layout()
    plt.show()

# %%
sns.distplot(two['mileage_in_km'],bins=20)
# Out:
# /tmp/ipython-input-1633842844.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(two['mileage_in_km'],bins=20)
# <Axes: xlabel='mileage_in_km', ylabel='Density'>

# %%
sns.distplot(np.log(df['price_in_euro']))
# Out:
# /tmp/ipython-input-3045226827.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.log(df['price_in_euro']))
# <Axes: xlabel='price_in_euro', ylabel='Density'>

# %%
sns.distplot(np.log(df['mileage_in_km']))
# Out:
# /tmp/ipython-input-2905496781.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.log(df['mileage_in_km']))
# <Axes: xlabel='mileage_in_km', ylabel='Density'>

# %%
sns.displot(df['mileage_in_km'])

# %%
plt.figure(figsize=(15,4))
sns.countplot(x=df['year'],palette="Paired")
plt.xlabel('Year')
plt.ylabel('Count')
plt.title('Year Distribution')
plt.show()#year 2019 selled more
# Out:
# /tmp/ipython-input-2078063817.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df['year'],palette="Paired")

# %%
plt.figure(figsize=(20,4))
sns.countplot(x=two['brand'],palette="Paired")
plt.xlabel('Brand')
plt.ylabel('Count')
plt.title('Brand Distribution')
plt.show()#brand
# Out:
# /tmp/ipython-input-2982714631.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=two['brand'],palette="Paired")

# %% [markdown]
# ford and audi selled more

# %% [markdown]
# Bivariant

# %%
plt.figure(figsize=(20,8))
plt.title('Brand Distribution')
sns.barplot(x=two['price_in_euro'],hue=two['brand'])
# Out:
# <Axes: title={'center': 'Brand Distribution'}, xlabel='price_in_euro'>

# %%
plt.figure(figsize=(20,6))
plt.title('Color Distribution')
sns.barplot(x=two['price_in_euro'],hue=two['color'])
# Out:
# <Axes: title={'center': 'Color Distribution'}, xlabel='price_in_euro'>

# %%
plt.figure(figsize=(20,6))

sns.barplot(x=two['transmission_type'],y=two['price_in_euro'])
# Out:
# <Axes: xlabel='transmission_type', ylabel='price_in_euro'>

# %%
plt.figure(figsize=(20,6))

sns.barplot(x=two['fuel_type'],y=two['price_in_euro'])
# Out:
# <Axes: xlabel='fuel_type', ylabel='price_in_euro'>

# %%
plt.figure(figsize=(20,6))
sns.lineplot(x=two['year'],y=two['price_in_euro'])
plt.xlabel('Year')
plt.ylabel('Price')
plt.title('Price Range')
plt.show()

# %%
plt.figure(figsize=(20,6))
sns.scatterplot(x=two['fuel_consumption_l_100km'],y=two['price_in_euro'])
plt.xlabel('fuel_consumption_l_100km')
plt.ylabel('Price')
plt.title('fuel')
plt.show()

# %%
plt.figure(figsize=(20,6))
sns.scatterplot(x=two['power_kw'],y=two['price_in_euro'])
plt.xlabel('power_kw')
plt.ylabel('Price')
plt.title('power_kw')
plt.show()

# %%
plt.figure(figsize=(20,6))
sns.scatterplot(x=two['power_ps'],y=two['price_in_euro'])
plt.xlabel('power_ps')
plt.ylabel('Price')
plt.title('power_ps')
plt.show()

# %%
df.columns
# Out:
# Index(['brand', 'model', 'color', 'year', 'price_in_euro', 'power_kw',
#        'power_ps', 'transmission_type', 'fuel_type',
#        'fuel_consumption_l_100km', 'fuel_consumption_g_km', 'mileage_in_km'],
#       dtype='object')

# %%
plt.figure(figsize=(12,4))
sns.scatterplot(y=df['price_in_euro'],x=df['year'])
# Out:
# <Axes: xlabel='year', ylabel='price_in_euro'>

# %% [markdown]
# Text

# %%
df.sort_values(by='mileage_in_km',ascending=False).head(2)
# Out:
#       brand       model   color  year  price_in_euro  power_kw  power_ps  \
# 80474  audi     Audi A4  silver  2001          900.0      85.0     116.0
# 14994   kia  Kia Carens   white  2014         5000.0      85.0     116.0
#
#       transmission_type fuel_type  fuel_consumption_l_100km  \
# 80474         Automatic    Diesel                       5.3
# 14994            Manual    Diesel                       4.8
#
#        fuel_consumption_g_km  mileage_in_km
# 80474                  143.0       500000.0
# 14994                  125.0       500000.0

# %%
df.sort_values(by='price_in_euro',ascending=False).head(2)
# Out:
#          brand             model   color  year  price_in_euro  power_kw  \
# 41882  bentley  Bentley Bentayga    grey  2017       150000.0     447.0
# 36536  ferrari       Ferrari 458  yellow  2010       150000.0     419.0
#
#        power_ps transmission_type fuel_type  fuel_consumption_l_100km  \
# 41882     608.0         Automatic    Petrol                      13.1
# 36536     570.0         Automatic    Petrol                       5.8
#
#        fuel_consumption_g_km  mileage_in_km
# 41882                  296.0        73000.0
# 36536                  139.0        64000.0

# %%
df.groupby('brand')['price_in_euro'].mean().sort_values(ascending=False).head(2)
# Out:
# brand
# lamborghini    123984.920000
# ferrari        115788.513699
# Name: price_in_euro, dtype: float64

# %%
ferrari=df[df['brand']=='ferrari'].sort_values(by='price_in_euro',ascending=False)
ferrari.head(2)
# Out:
#          brand         model   color  year  price_in_euro  power_kw  power_ps  \
# 36536  ferrari   Ferrari 458  yellow  2010       150000.0     419.0     570.0
# 46541  ferrari  Ferrari F430     red  2006       149988.0     360.0     489.0
#
#       transmission_type fuel_type  fuel_consumption_l_100km  \
# 36536         Automatic    Petrol                       5.8
# 46541         Automatic    Petrol                      18.3
#
#        fuel_consumption_g_km  mileage_in_km
# 36536                  139.0        64000.0
# 46541                  420.0        18000.0

# %%
plt.figure(figsize=(20,6))
sns.barplot(x=ferrari['color'],y=ferrari['price_in_euro'],hue=ferrari['color'],width=0.5)
plt.xlabel('Brand')
plt.ylabel('Price')
plt.title('Price Range')
plt.show()
